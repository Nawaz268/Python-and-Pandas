# %%
import pandas as pd
from pandas_datareader import data

# %%
companies = ["MSFT", "GOOG", "AAPL","YHOO" "AMZN"]




p = data.DataReader(name = companies, data_source = "iex", start
                    = "2010-01-01", end ="2016-12-31")

type(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-fed9f49d5069> in <module>
#       5
#       6 p = data.DataReader(name = companies, data_source = "iex", start
# ----> 7                     = "2010-01-01", end ="2016-12-31")
#       8
#       9 type(p)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     320                               chunksize=25,
#     321                               retry_count=retry_count, pause=pause,
# --> 322                               session=session).read()
#     323
#     324     elif data_source == "iex-tops":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_datareader/iex/daily.py in read(self)
#      89         try:
#      90             return self._read_one_data(self.url,
# ...

# %%
p
# Out:
# Attributes        High                                            Low  \
# Symbols           AAPL        AMZN        GOOG       MSFT        AAPL
# Date
# 2010-01-04   30.642857  136.610001  312.721039  31.100000   30.340000
# 2010-01-05   30.798571  135.479996  311.891449  31.100000   30.464285
# 2010-01-06   30.747143  134.729996  310.907837  31.080000   30.107143
# 2010-01-07   30.285715  132.320007  303.029083  30.700001   29.864286
# 2010-01-08   30.285715  133.679993  299.675903  30.879999   29.865715
# 2010-01-11   30.428572  132.800003  300.276978  30.760000   29.778572
# 2010-01-12   29.967142  129.820007  297.147339  30.400000   29.488571
# 2010-01-13   30.132856  129.710007  292.288940  30.520000   29.157143
# 2010-01-14   30.065714  130.380005  295.180145  31.100000   29.860001
# 2010-01-15   30.228571  129.649994  294.862213  31.240000   29.410000
# 2010-01-19   30.741428  128.000000  293.302338  31.240000   29.605715
# ...

# %%
p.items
# Out:
# <bound method DataFrame.iteritems of Attributes        High                                            Low  \
# Symbols           AAPL        AMZN        GOOG       MSFT        AAPL
# Date
# 2010-01-04   30.642857  136.610001  312.721039  31.100000   30.340000
# 2010-01-05   30.798571  135.479996  311.891449  31.100000   30.464285
# 2010-01-06   30.747143  134.729996  310.907837  31.080000   30.107143
# 2010-01-07   30.285715  132.320007  303.029083  30.700001   29.864286
# 2010-01-08   30.285715  133.679993  299.675903  30.879999   29.865715
# 2010-01-11   30.428572  132.800003  300.276978  30.760000   29.778572
# 2010-01-12   29.967142  129.820007  297.147339  30.400000   29.488571
# 2010-01-13   30.132856  129.710007  292.288940  30.520000   29.157143
# 2010-01-14   30.065714  130.380005  295.180145  31.100000   29.860001
# 2010-01-15   30.228571  129.649994  294.862213  31.240000   29.410000
# 2010-01-19   30.741428  128.000000  293.302338  31.240000   29.605715
# ...

# %%
p.major_axis
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-5cdf808b2fac> in <module>
# ----> 1 p.major_axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'DataFrame' object has no attribute 'major_axis'
